# %%
## 7.4
things = ["mozzarella", "cinderella", "salmonella"]
print("7.4: " + str(things))

## 7.5
things[1] = things[1].capitalize()
print("7.5: " + str(things))
## The order is still the same, but the string got capitalized, so nothing really changed

## 7.6
things[0] = things[0].capitalize()
print("7.6: " + str(things))

## 7.7
things.remove("salmonella")
print("7.7: " + str(things))
# Out:
# 7.4: ['mozzarella', 'cinderella', 'salmonella']
# 7.5: ['mozzarella', 'Cinderella', 'salmonella']
# 7.6: ['Mozzarella', 'Cinderella', 'salmonella']
# 7.7: ['Mozzarella', 'Cinderella']

# %%
## 9.1
def good():
    return ['Harry', 'Ron', 'Hermione']

print("9.1: ")
print(good())

## 9.2
def get_odds():
    for num in range(10):
        if num % 2 == 1:
            yield num

count = 0
for num in get_odds():
    count += 1
    if count >= 3:
        print("9.2: ")
        print("third value: " + str(num))
        break
# Out:
# 9.1:
# ['Harry', 'Ron', 'Hermione']
# 9.2:
# third value: 5
