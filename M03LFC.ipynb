# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

class Automobile(Vehicle):
    def __init__(self, year, make, model, doors, roof):
        super().__init__("car")
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof

year = input("Car year: ")
make = input("Car make: ")
model = input("Car model: ")
doors = input("Total car doors [2-4]: ")
roof = input("Car roof [sun or solid]: ")

car = Automobile(year, make, model, doors, roof)
        
## CAR OUTPUT
print("\n" + "===== VEHICLE INFORMATION =====")
print(f"Vehicle type: {car.vehicle_type}")
print(f"Year: {car.year}")
print(f"Make: {car.make}")
print(f"Model: {car.model}")
print(f"Number of doors: {car.doors}")
print(f"Type of roof: {car.roof}")
# Out:
# Car year:  2026
# Car make:  Lamborghini
# Car model:  Urus
# Total car doors [2-4]:  4
# Car roof [sun or solid]:  solid
# Vehicle type: car
# Year: 2026
# Make: Lamborghini
# Model: Urus
# Number of doors: 4
# Type of roof: solid
